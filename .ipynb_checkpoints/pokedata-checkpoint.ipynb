# %% [markdown]
# import pandas as pd
# import requests
# import json
#
# def flavorText(pokenum):
#     r = requests.get("https://pokeapi.co/api/v2/pokemon-species/" + str(pokenum))
#     resp = json.loads(r.text)
#     flavortext = resp['flavor_text_entries']
#     for x in flavortext:
#         if '/1/' in x['version']['url'] and x['language']['name'] == 'en':
#             x = x['flavor_text'].replace('\n', ' ')
#     return(x)
#
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# pd.set_optkon('display.max_colwidth', -1)

# %% [markdown]
# ## Load CSV from Github into DF
# https://raw.githubusercontent.com/ryan-black-wd/pandas-demo/master/pokemon.csv

# %% [markdown]
# ## Process the data
# Remove all rows that have the string 'Mega' in the 'Name' co

# %%
# Process/Filter Data
df = df[~df['Name'].str.contains('Mega')]
df = df[df['Generation'] == 1]
df = df.fillna('None')
df['Flavor Text'] = df['#'].apply(flavorText)

# %%
# Get columns
cols = []
for col in df.columns:
    cols.append(col)

# %%
# Group by Type
df = df.groupby(['Type 1', 'Type 2', 'Name', 'Flavor Text'])[cols[4:]].mean().reset_index()

# %%
fastest = df[df['Speed'] == df.groupby(['Type 1'])['Speed'].transform(max)]
fastest
# Out:
#        Type 1   Type 2        Name  \
# 1    Bug       Flying   Scyther
# 12   Dragon    Flying   Dragonite
# 17   Electric  None     Electrode
# 24   Fairy     None     Clefable
# 32   Fighting  None     Primeape
# 43   Fire      None     Rapidash
# 46   Ghost     Poison   Gengar
# 54   Grass     Poison   Venusaur
# 62   Ground    None     Dugtrio
# 69   Ice       Psychic  Jynx
# 86   Normal    None     Persian
# 92   Poison    Flying   Golbat
# 113  Psychic   None     Mewtwo
# 114  Rock      Flying   Aerodactyl
# 150  Water     Psychic  Starmie
#
#                                                                                                Flavor Text  \
# 1    With ninja-like agility and speed, it can create theillusion that there is more than one.
# 12   An extremely rarely seen marine POKéMON.Its intelligence is said to match that of humans.
# 17   It stores electric energy under very high pressure.It often explodes with little or no provocation.
# 24   A timid fairy POKéMON that is rarely seen. Itwill run and hide the moment it senses people.
# 32   Always furious and tenacious to boot. It will notabandon chasing its quarry until it is caught.
# 43   Very competitive, this POKéMON will chase anythingthat moves fast in the hopes of racing it.
# 46   Under a full moon, this POKéMON likes to mimicthe shadows of people and laugh at their fright.
# 54   The plant blooms when it is absorbing solarenergy. It stays on the move to seek sunlight.
# 62   A team of DIGLETT triplets. It triggers hugeearthquakes by burrowing 60 miles underground.
# 69   It seductively wiggles its hips as it walks. Itcan cause people to dance in unison with it.
# 86   Although its fur has many admirers, it is tough toraise as a pet because of its fickle meanness.
# 92   Once it strikes, it will not stop draining energyfrom the victim even if it gets too heavy to fly.
# 113  It was created by a scientist after years of horrificgene splicing and DNA engineering experiments.
# 114  A ferocious, pre­ historic POKéMON that goes for theenemy's throat with its serrated saw-like fangs.
# 150  Its central core glows with the seven colors ofthe rainbow. Some people value the core as a gem.
#
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 1    500    70   110     80       55       80       105    1
# 12   600    91   134     95       100      100      80     1
# 17   480    60   50      70       80       80       140    1
# 24   483    95   70      73       95       90       60     1
# 32   455    65   105     60       60       70       95     1
# 43   500    65   100     70       80       80       105    1
# 46   500    60   65      60       130      75       110    1
# 54   525    80   82      83       100      100      80     1
# 62   405    35   80      50       50       70       120    1
# 69   455    65   50      35       115      95       95     1
# 86   440    65   70      60       65       65       115    1
# 92   455    75   80      70       65       75       90     1
# 113  680    106  110     90       154      90       130    1
# 114  515    80   105     65       60       75       130    1
# 150  520    60   75      85       100      85       115    1
#
#      Legendary
# 1    False
# 12   False
# 17   False
# 24   False
# 32   False
# 43   False
# 46   False
# 54   False
# 62   False
# 69   False
# 86   False
# 92   False
# 113  True
# 114  False
# 150  False
